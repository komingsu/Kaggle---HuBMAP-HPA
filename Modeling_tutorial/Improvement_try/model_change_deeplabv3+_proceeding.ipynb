# %% [markdown]
# <a href="https://colab.research.google.com/github/komingsu/Kaggle---HuBMAP-HPA/blob/main/Modeling/Model_Improvement/model_change_deeplabv3%2B_proceeding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import utils, layers, models, applications
from tensorflow._api.v2.image import ResizeMethod

# %%
# Entry Flow

def entry_flow(x) : 
  y = layers.Conv2D(filters = 32, kernel_size = (3,3), strides = (2,2))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.Conv2D(filters = 64, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)

  r = layers.Conv2D(128, kernel_size = (1,1), strides = (2,2))(y)

  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3), strides = (2,2))(y)

  # residual과 resolution이 약간 달라서 reshape
  y = layers.Resizing(r.shape[1], r.shape[2])(y)
  z1 = tf.concat([y,r],-1)
  z1 = layers.BatchNormalization()(z1)
  z1 = layers.Activation('relu')(z1)


  r = layers.Conv2D(256, kernel_size = (1,1), strides = (2,2))(z1)

  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(z1)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3), strides = (2,2))(y)
  y = layers.Resizing(r.shape[1], r.shape[2])(y)

  z = tf.concat([y,r],-1)
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  r = layers.Conv2D(728, kernel_size = (1,1), strides = (2,2))(z)

  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(z)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3), strides = (2,2))(y)
  y = layers.Resizing(r.shape[1], r.shape[2])(y)

  z = tf.concat([y,r],-1)
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  return z,z1

# %%
# Middle flow

def middle_flow(x) :
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y) 
  y = layers.Resizing(x.shape[1], x.shape[2])(y)

  z = tf.concat([y,x],-1)
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)
  return z

# %%
# Exit flow

def exit_flow(x) :
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3), strides = (2,2))(y)
  x = layers.SeparableConv2D(filters = 1024, kernel_size = (1,1), strides = (1,1))(x)
  y = layers.Resizing(x.shape[1], x.shape[2])(y)


  z = tf.concat([y,x],-1)
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(z)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 2048, kernel_size = (3,3))(y)
  return y

# %%
def decoder(low_img, aspp_img) :
  from tensorflow._api.v2.image import ResizeMethod
  low_level_img = layers.Conv2D(2048, kernel_size = (1,1))(low_img)   # ASPP 통과한 이미지와 채널 수 맞춤

  size = (low_img.shape[1],low_img.shape[2]) # resize img
  ASPP_img = tf.image.resize(aspp_img, size = size, method = ResizeMethod.BILINEAR)    # low level 이미지와 ASPP 통과한 이미지 resolution 맞춤

  concat_img = tf.concat([low_level_img, ASPP_img], axis = -1)

  concat_img = layers.Conv2D(2, kernel_size = (3,3))(concat_img)
  img = tf.image.resize(concat_img, size = (3000,3000), method = ResizeMethod.BILINEAR)

  return img

# %%
# optimizer
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


# loss
def weighted_loss(y_true, y_pred):
# Calculate the base loss
  from tensorflow.keras.losses import binary_crossentropy
  bc = binary_crossentropy(y_true, y_pred)
  # Apply the weights
  one_weight = 1.0
  zero_weight = 1e-2
  weight_vector = y_true * one_weight + (1. - y_true) * zero_weight
  weight_vector = K.squeeze(weight_vector, axis=-1)
  weighted_ce = weight_vector * bc
  # Return the mean error
  return K.mean(weighted_ce)

# %%
def deeplabv3(input_shape) :
  x = layers.Input(input_shape)
  z, low_level_feature = entry_flow(x)
  z = middle_flow(z)
  ASPP_feature = exit_flow(z)
  output =  decoder(low_level_feature, ASPP_feature)
  model = models.Model(x, output)
  model.compile(loss=weighted_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),metrics=['accuracy', dice_coef])
  return model

# %%
input_shape = (3000,3000,1)
model = deeplabv3(input_shape)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 3000, 3000,  0           []
#                                  1)]
#
#  conv2d_94 (Conv2D)             (None, 1499, 1499,   320         ['input_23[0][0]']
#                                 32)
#
#  batch_normalization_201 (Batch  (None, 1499, 1499,   128        ['conv2d_94[0][0]']
#  Normalization)                 32)
#
#  activation_201 (Activation)    (None, 1499, 1499,   0           ['batch_normalization_201[0][0]']
#                                 32)
#
#  conv2d_95 (Conv2D)             (None, 1497, 1497,   18496       ['activation_201[0][0]']
#                                 64)
#
#  batch_normalization_202 (Batch  (None, 1497, 1497,   256        ['conv2d_95[0][0]']
#  Normalization)                 64)
#
#  activation_202 (Activation)    (None, 1497, 1497,   0           ['batch_normalization_202[0][0]']
#                                 64)
#
#  separable_conv2d_187 (Separabl  (None, 1495, 1495,   8896       ['activation_202[0][0]']
#  eConv2D)                       128)
#
#  batch_normalization_203 (Batch  (None, 1495, 1495,   512        ['separable_conv2d_187[0][0]']
#  Normalization)                 128)
#
#  activation_203 (Activation)    (None, 1495, 1495,   0           ['batch_normalization_203[0][0]']
#                                 128)
#
#  separable_conv2d_188 (Separabl  (None, 1493, 1493,   17664      ['activation_203[0][0]']
#  eConv2D)                       128)
#
#  batch_normalization_204 (Batch  (None, 1493, 1493,   512        ['separable_conv2d_188[0][0]']
#  Normalization)                 128)
#
#  activation_204 (Activation)    (None, 1493, 1493,   0           ['batch_normalization_204[0][0]']
#                                 128)
#
#  separable_conv2d_189 (Separabl  (None, 746, 746, 12  17664      ['activation_204[0][0]']
#  eConv2D)                       8)
#
#  resizing_53 (Resizing)         (None, 749, 749, 12  0           ['separable_conv2d_189[0][0]']
#                                 8)
#
#  conv2d_96 (Conv2D)             (None, 749, 749, 12  8320        ['activation_202[0][0]']
#                                 8)
#
#  tf.concat_45 (TFOpLambda)      (None, 749, 749, 25  0           ['resizing_53[0][0]',
#                                 6)                                'conv2d_96[0][0]']
#
#  batch_normalization_205 (Batch  (None, 749, 749, 25  1024       ['tf.concat_45[0][0]']
#  Normalization)                 6)
#
#  activation_205 (Activation)    (None, 749, 749, 25  0           ['batch_normalization_205[0][0]']
#                                 6)
#
#  separable_conv2d_190 (Separabl  (None, 747, 747, 25  68096      ['activation_205[0][0]']
#  eConv2D)                       6)
#
#  batch_normalization_206 (Batch  (None, 747, 747, 25  1024       ['separable_conv2d_190[0][0]']
#  Normalization)                 6)
#
#  activation_206 (Activation)    (None, 747, 747, 25  0           ['batch_normalization_206[0][0]']
#                                 6)
#
#  separable_conv2d_191 (Separabl  (None, 745, 745, 25  68096      ['activation_206[0][0]']
#  eConv2D)                       6)
#
#  batch_normalization_207 (Batch  (None, 745, 745, 25  1024       ['separable_conv2d_191[0][0]']
#  Normalization)                 6)
#
#  activation_207 (Activation)    (None, 745, 745, 25  0           ['batch_normalization_207[0][0]']
#                                 6)
#
#  separable_conv2d_192 (Separabl  (None, 372, 372, 25  68096      ['activation_207[0][0]']
#  eConv2D)                       6)
#
#  resizing_54 (Resizing)         (None, 375, 375, 25  0           ['separable_conv2d_192[0][0]']
#                                 6)
#
#  conv2d_97 (Conv2D)             (None, 375, 375, 25  65792       ['activation_205[0][0]']
#                                 6)
#
#  tf.concat_46 (TFOpLambda)      (None, 375, 375, 51  0           ['resizing_54[0][0]',
#                                 2)                                'conv2d_97[0][0]']
#
#  batch_normalization_208 (Batch  (None, 375, 375, 51  2048       ['tf.concat_46[0][0]']
#  Normalization)                 2)
#
#  activation_208 (Activation)    (None, 375, 375, 51  0           ['batch_normalization_208[0][0]']
#                                 2)
#
#  separable_conv2d_193 (Separabl  (None, 373, 373, 72  378072     ['activation_208[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_209 (Batch  (None, 373, 373, 72  2912       ['separable_conv2d_193[0][0]']
#  Normalization)                 8)
#
#  activation_209 (Activation)    (None, 373, 373, 72  0           ['batch_normalization_209[0][0]']
#                                 8)
#
#  separable_conv2d_194 (Separabl  (None, 371, 371, 72  537264     ['activation_209[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_210 (Batch  (None, 371, 371, 72  2912       ['separable_conv2d_194[0][0]']
#  Normalization)                 8)
#
#  activation_210 (Activation)    (None, 371, 371, 72  0           ['batch_normalization_210[0][0]']
#                                 8)
#
#  separable_conv2d_195 (Separabl  (None, 185, 185, 72  537264     ['activation_210[0][0]']
#  eConv2D)                       8)
#
#  resizing_55 (Resizing)         (None, 188, 188, 72  0           ['separable_conv2d_195[0][0]']
#                                 8)
#
#  conv2d_98 (Conv2D)             (None, 188, 188, 72  373464      ['activation_208[0][0]']
#                                 8)
#
#  tf.concat_47 (TFOpLambda)      (None, 188, 188, 14  0           ['resizing_55[0][0]',
#                                 56)                               'conv2d_98[0][0]']
#
#  batch_normalization_211 (Batch  (None, 188, 188, 14  5824       ['tf.concat_47[0][0]']
#  Normalization)                 56)
#
#  activation_211 (Activation)    (None, 188, 188, 14  0           ['batch_normalization_211[0][0]']
#                                 56)
#
#  separable_conv2d_196 (Separabl  (None, 186, 186, 72  1073800    ['activation_211[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_212 (Batch  (None, 186, 186, 72  2912       ['separable_conv2d_196[0][0]']
#  Normalization)                 8)
#
#  activation_212 (Activation)    (None, 186, 186, 72  0           ['batch_normalization_212[0][0]']
#                                 8)
#
#  separable_conv2d_197 (Separabl  (None, 184, 184, 72  537264     ['activation_212[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_213 (Batch  (None, 184, 184, 72  2912       ['separable_conv2d_197[0][0]']
#  Normalization)                 8)
#
#  activation_213 (Activation)    (None, 184, 184, 72  0           ['batch_normalization_213[0][0]']
#                                 8)
#
#  separable_conv2d_198 (Separabl  (None, 182, 182, 72  537264     ['activation_213[0][0]']
#  eConv2D)                       8)
#
#  resizing_56 (Resizing)         (None, 188, 188, 72  0           ['separable_conv2d_198[0][0]']
#                                 8)
#
#  tf.concat_48 (TFOpLambda)      (None, 188, 188, 21  0           ['resizing_56[0][0]',
#                                 84)                               'activation_211[0][0]']
#
#  batch_normalization_214 (Batch  (None, 188, 188, 21  8736       ['tf.concat_48[0][0]']
#  Normalization)                 84)
#
#  activation_214 (Activation)    (None, 188, 188, 21  0           ['batch_normalization_214[0][0]']
#                                 84)
#
#  separable_conv2d_199 (Separabl  (None, 186, 186, 72  1610336    ['activation_214[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_215 (Batch  (None, 186, 186, 72  2912       ['separable_conv2d_199[0][0]']
#  Normalization)                 8)
#
#  activation_215 (Activation)    (None, 186, 186, 72  0           ['batch_normalization_215[0][0]']
#                                 8)
#
#  separable_conv2d_200 (Separabl  (None, 184, 184, 10  753048     ['activation_215[0][0]']
#  eConv2D)                       24)
#
#  batch_normalization_216 (Batch  (None, 184, 184, 10  4096       ['separable_conv2d_200[0][0]']
#  Normalization)                 24)
#
#  activation_216 (Activation)    (None, 184, 184, 10  0           ['batch_normalization_216[0][0]']
#                                 24)
#
#  separable_conv2d_201 (Separabl  (None, 91, 91, 1024  1058816    ['activation_216[0][0]']
#  eConv2D)                       )
#
#  resizing_57 (Resizing)         (None, 188, 188, 10  0           ['separable_conv2d_201[0][0]']
#                                 24)
#
#  separable_conv2d_202 (Separabl  (None, 188, 188, 10  2239624    ['activation_214[0][0]']
#  eConv2D)                       24)
#
#  tf.concat_49 (TFOpLambda)      (None, 188, 188, 20  0           ['resizing_57[0][0]',
#                                 48)                               'separable_conv2d_202[0][0]']
#
#  batch_normalization_217 (Batch  (None, 188, 188, 20  8192       ['tf.concat_49[0][0]']
#  Normalization)                 48)
#
#  activation_217 (Activation)    (None, 188, 188, 20  0           ['batch_normalization_217[0][0]']
#                                 48)
#
#  separable_conv2d_203 (Separabl  (None, 186, 186, 15  3165696    ['activation_217[0][0]']
#  eConv2D)                       36)
#
#  batch_normalization_218 (Batch  (None, 186, 186, 15  6144       ['separable_conv2d_203[0][0]']
#  Normalization)                 36)
#
#  activation_218 (Activation)    (None, 186, 186, 15  0           ['batch_normalization_218[0][0]']
#                                 36)
#
#  separable_conv2d_204 (Separabl  (None, 184, 184, 15  2374656    ['activation_218[0][0]']
#  eConv2D)                       36)
#
#  batch_normalization_219 (Batch  (None, 184, 184, 15  6144       ['separable_conv2d_204[0][0]']
#  Normalization)                 36)
#
#  activation_219 (Activation)    (None, 184, 184, 15  0           ['batch_normalization_219[0][0]']
#                                 36)
#
#  separable_conv2d_205 (Separabl  (None, 182, 182, 20  3161600    ['activation_219[0][0]']
#  eConv2D)                       48)
#
#  conv2d_99 (Conv2D)             (None, 749, 749, 20  526336      ['activation_205[0][0]']
#                                 48)
#
#  tf.image.resize_14 (TFOpLambda  (None, 749, 749, 20  0          ['separable_conv2d_205[0][0]']
#  )                              48)
#
#  tf.concat_50 (TFOpLambda)      (None, 749, 749, 40  0           ['conv2d_99[0][0]',
#                                 96)                               'tf.image.resize_14[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 747, 747, 2)  73730       ['tf.concat_50[0][0]']
#
#  tf.image.resize_15 (TFOpLambda  (None, 3000, 3000,   0          ['conv2d_100[0][0]']
#  )                              2)
#
# ==================================================================================================
# Total params: 19,339,898
# Trainable params: 19,309,786
# Non-trainable params: 30,112
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes = True)
